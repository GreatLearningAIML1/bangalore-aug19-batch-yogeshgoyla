# %% [markdown]
# # Problem Statement -
#
# Build your own recommendation system for products on an e-commerce website like Amazon.com.
# Dataset Link -
# https://drive.google.com/file/d/1ClBptsK3V5KgKXtK2GSRzFNAW7GnTPDW/view?usp=sharing

# %% [markdown]
# Dataset columns - first three columns are userId, productId, and ratings and the fourth column is
# timestamp. You can discard the timestamp column as in this case you may not need to use it.
#
# Source - Amazon Reviews data (http://jmcauley.ucsd.edu/data/amazon/) The repository has
# several datasets. For this case study, we are using the Electronics dataset.

# %% [markdown]
# Following steps are expected:
#
# 1. Read and explore the given dataset. ( Rename column/add headers, plot histograms,find data characteristics)
# 2. Take a subset of the dataset to make it less sparse/ denser. ( For example, keep the users only who has given 50 or more number of ratings )
# 3. Build Popularity Recommender model.
# 4. Split the data randomly into train and test dataset. ( For example, split it in 70/30 ratio)
# 5. Build Collaborative Filtering model.
# 6. Evaluate the above model. ( Once the model is trained on the training data, it can be used to compute the error (like RMSE) on predictions made on the test data.) You can also use a different method to evaluate the models.
# 7. Get top - K ( K = 5) recommendations. Since our goal is to recommend new products to each user based on his/her habits, we will recommend 5 new products.
# 8. Summarise your insights.

# %% [markdown]
# Please Note -
#
# ● If you are facing any memory issue while working on this project, create a small subset (Let’ say 10% of data) and work on it.
#
# ● If you are stuck at the model evaluation part of this project.Please refer to below links -
# 1. https://surprise.readthedocs.io/en/stable/accuracy.html
# 2. http://surpriselib.com/ - Getting started, example

# %% [markdown]
# # Attribute Information:
#
# ● userId : Every user identified with a unique id
#
# ● productId : Every product identified with a unique id
#
# ● Rating : Rating of the corresponding product by the corresponding user
#
# ● timestamp : Time of the rating ( ignore this column for this exercise)

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import math
import json
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.externals import joblib
import scipy.sparse
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # Read the Dataset, specify column headers

# %%
electronics_data=pd.read_csv("ratings_Electronics.csv",names=['userId', 'productId','Rating','timestamp'])

# %%
# Display the first 5 rows

electronics_data.head()
# Out:
#            userId   productId  Rating   timestamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200

# %%
#Data frame Shape 
electronics_data.shape
# Out:
# (7824482, 4)

# %%
#Taking subset of the dataset
electronics_data=electronics_data.iloc[:48576,0:]

# %%
#Check the datatypes
electronics_data.dtypes
# Out:
# userId        object
# productId     object
# Rating       float64
# timestamp      int64
# dtype: object

# %%
electronics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48576 entries, 0 to 48575
# Data columns (total 4 columns):
# userId       48576 non-null object
# productId    48576 non-null object
# Rating       48576 non-null float64
# timestamp    48576 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
#Five point summary based upon ratings

electronics_data.describe()['Rating'].T
# Out:
# count    48576.000000
# mean         4.030797
# std          1.361419
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: Rating, dtype: float64

# %%
#Find the minimum and maximum ratings
print('Minimum rating is: %d' %(electronics_data.Rating.min()))
print('Maximum rating is: %d' %(electronics_data.Rating.max()))
# Out:
# Minimum rating is: 1
# Maximum rating is: 5

# %% [markdown]
# The rating of the product range from 1 to 5

# %% [markdown]
# ## Looking for Missing values

# %%
#Check for missing values
print('Number of missing values across columns: \n',electronics_data.isnull().sum())
# Out:
# Number of missing values across columns:
#  userId       0
# productId    0
# Rating       0
# timestamp    0
# dtype: int64

# %% [markdown]
# ## Ratings distribution

# %%
# Check the distribution of the rating
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Rating", data=electronics_data, aspect=1.0,kind='count')
    g.set_ylabels("Total number of ratings")

# %% [markdown]
# Most of the people has given the rating of 5

# %% [markdown]
# ## finding out unique users and products

# %%
print("Total data ")
print("-"*50)
print("\nTotal no of ratings :",electronics_data.shape[0])
print("Total No of Users   :", len(np.unique(electronics_data.userId)))
print("Total No of products  :", len(np.unique(electronics_data.productId)))
# Out:
# Total data
# --------------------------------------------------
#
# Total no of ratings : 48576
# Total No of Users   : 45204
# Total No of products  : 3397

# %% [markdown]
# ## Dropping the TimeStamp Column

# %%
#Dropping the Timestamp column

electronics_data.drop(['timestamp'], axis=1,inplace=True)

# %% [markdown]
# # Analysis of the ratings

# %%
#Analysis of rating given by the user 

no_of_rated_products_per_user = electronics_data.groupby(by='userId')['Rating'].count().sort_values(ascending=False)

no_of_rated_products_per_user.head()
# Out:
# userId
# A231WM2Z2JL0U3    35
# AY8Q1X7G96HV5     27
# ALUNVOQRXOZIA     20
# A1NVD0TKNS1GT5    19
# A243HY69GIAHFI    18
# Name: Rating, dtype: int64

# %%
no_of_rated_products_per_user.describe()
# Out:
# count    45204.000000
# mean         1.074595
# std          0.516619
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         35.000000
# Name: Rating, dtype: float64

# %%
print('\n No of rated product having more than 50 user reviews: {}\n'.format(sum(no_of_rated_products_per_user >= 50)) )
# Out:
#  No of rated product having more than 50 user reviews: 0

# %% [markdown]
# # Popularity Based Recommendation
#
# Popularity based recommendation system works on the trending data. For instance, if any product which is usually bought by every new user then there are chances that it may suggest that item to the user who just signed up to the e-commerce website. The drawback of the popularity based recommendation system is that the user based personalization is not available i.e. even though you know the behaviour of the user but you cannot recommend items accordingly.

# %%
#Getting the new dataframe which contains users who has given 50 or more ratings

new_df=electronics_data.groupby("productId").filter(lambda x:x['Rating'].count() >=50)

# %%
no_of_ratings_per_item = new_df.groupby(by='productId')['Rating'].count().sort_values(ascending=False)

fig = plt.figure(figsize=plt.figaspect(1))
ax = plt.gca()
plt.plot(no_of_ratings_per_item.values)
plt.title('No. of Ratings per product')
plt.xlabel('Products ->')
plt.ylabel('No of Users who rated the product')
ax.set_xticklabels([])

plt.show()
# Out:
# Text(0.5, 1.0, 'No. of Ratings per product')
# Text(0.5, 0, 'Products ->')
# Text(0, 0.5, 'No of Users who rated the product')
# []

# %%
#Average rating of the product 

new_df.groupby('productId')['Rating'].mean().head()
# Out:
# productId
# 0972683275    4.470980
# 1400501466    3.560000
# 1400501520    4.243902
# 1400501776    3.884892
# 1400532620    3.684211
# Name: Rating, dtype: float64

# %%
new_df.groupby('productId')['Rating'].mean().sort_values(ascending=False).head()
# Out:
# productId
# B00004TDLD    4.840517
# B00004TENT    4.823529
# B00000J4EY    4.735294
# B00000JDF6    4.708738
# B00004SY4H    4.705882
# Name: Rating, dtype: float64

# %%
#Total no of rating for product

new_df.groupby('productId')['Rating'].count().sort_values(ascending=False).head()
# Out:
# productId
# B00001P4ZH    2075
# B00004T8R2    1692
# B00001WRSJ    1586
# 0972683275    1051
# B00004SABB    1030
# Name: Rating, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(new_df.groupby('productId')['Rating'].mean())

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(new_df.groupby('productId')['Rating'].count())

# %%
ratings_mean_count.head()
# Out:
#               Rating  rating_counts
# productId
# 0972683275  4.470980           1051
# 1400501466  3.560000            250
# 1400501520  4.243902             82
# 1400501776  3.884892            139
# 1400532620  3.684211            171

# %%
ratings_mean_count['rating_counts'].max()
# Out:
# 2075

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x='Rating', y='rating_counts', data=ratings_mean_count, alpha=0.4)

# %%
popular_products = pd.DataFrame(new_df.groupby('productId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)
most_popular.head(30).plot(kind = "bar")

# %% [markdown]
# # Collaberative filtering model (Item-Item recommedation)
#
# Collaborative filtering is commonly used in the recommendation systems. This techniques aim to impute the missing entries of a user-item association matrix. CF is based on the idea that the best recommendations come from people who have similar tastes. In other words, it uses historical item ratings of like-minded people to predict how someone would rate an item. Collaborative filtering has two sub-categories that are generally called memory based and model-based approaches.

# %%
from surprise import KNNWithMeans
from surprise import NormalPredictor
from surprise import BaselineOnly
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate

# %%
#Reading the dataset
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(new_df,reader)

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=2, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse   fit_time  test_time
# Algorithm
# BaselineOnly      1.239116   0.061504   0.089520
# KNNBaseline       1.241671  10.376872   0.370525
# SVD               1.242017   1.010071   0.104931
# SVDpp             1.251397   1.918776   0.122272
# KNNBasic          1.302671  10.142938   0.692865
# KNNWithZScore     1.305340   9.104279   0.549678
# KNNWithMeans      1.306242  10.260013   0.325377
# SlopeOne          1.306464   0.136137   0.082106
# CoClustering      1.307615   1.617804   0.112345
# NMF               1.308183   2.206957   0.091037
# NormalPredictor   1.659493   0.025759   0.108395

# %%
surprise_results = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')

# %%
surprise_results
# Out:
#                  test_rmse   fit_time  test_time
# Algorithm
# BaselineOnly      1.239116   0.061504   0.089520
# KNNBaseline       1.241671  10.376872   0.370525
# SVD               1.242017   1.010071   0.104931
# SVDpp             1.251397   1.918776   0.122272
# KNNBasic          1.302671  10.142938   0.692865
# KNNWithZScore     1.305340   9.104279   0.549678
# KNNWithMeans      1.306242  10.260013   0.325377
# SlopeOne          1.306464   0.136137   0.082106
# CoClustering      1.307615   1.617804   0.112345
# NMF               1.308183   2.206957   0.091037
# NormalPredictor   1.659493   0.025759   0.108395

# %%
print('Using ALS')
bsl_options = {'method': 'als',
               'n_epochs': 5,
               'reg_u': 12,
               'reg_i': 5
               }
algo = BaselineOnly(bsl_options=bsl_options)
cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Using ALS
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# {'test_rmse': array([1.23120415, 1.25105168, 1.23019981]),
#  'fit_time': (0.0763852596282959, 0.06943988800048828, 0.05158352851867676),
#  'test_time': (0.07390213012695312, 0.13788819313049316, 0.06051182746887207)}

# %%
#Splitting the dataset in 70/30 ratio
trainset, testset = train_test_split(data, test_size=0.3,random_state=20)

# %%
# Use user_based true/false to switch between user-based or item-based collaborative filtering
#algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...

# %%
# run the trained model against the testset
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A36Z3EML39QNVK', iid='B00001ZWXA', r_ui=4.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='AZTC7YC8PKG39', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A3DSH3DJGQSEFU', iid='B00004RFB8', r_ui=5.0, est=2.246840572831596, details={'was_impossible': False}),
#  Prediction(uid='AHKLKGLLMS5R5', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A25I7SLBDDGK0A', iid='B00001W0DD', r_ui=5.0, est=3.897402633239058, details={'was_impossible': False}),
#  Prediction(uid='A3TLZ39PXJJ7QV', iid='B00004SB92', r_ui=5.0, est=4.054329445854627, details={'was_impossible': False}),
#  Prediction(uid='A29L27JP5Z7DMJ', iid='9983891212', r_ui=5.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='A2XQEB2JYDG1L8', iid='B00000J1V5', r_ui=5.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A2KY7I1B1BO96S', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3V386W6Z1QR7P', iid='B00000J08Q', r_ui=1.0, est=2.663262562610353, details={'was_impossible': False}),
#  Prediction(uid='A2BR01CI7K7GAN', iid='B00001ZT4H', r_ui=5.0, est=4.178011151599929, details={'was_impossible': False}),
#  Prediction(uid='A2T07G80FXRZGO', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A20UU20K7M9ZPF', iid='140053271X', r_ui=1.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A1HU6H3B7O9681', iid='B00000J1EJ', r_ui=5.0, est=3.1507313271319846, details={'was_impossible': False}),
#  Prediction(uid='A1G8M145YQAAF6', iid='B00000J4FS', r_ui=5.0, est=3.9664069885343927, details={'was_impossible': False}),
#  Prediction(uid='A281Y68EQ18UA6', iid='B00001P4ZH', r_ui=4.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3J5E2VJRG6KO6', iid='B00003006K', r_ui=3.0, est=4.283890183118284, details={'was_impossible': False}),
#  Prediction(uid='AB82BK91DQJRC', iid='B00003006R', r_ui=1.0, est=3.7875140332929624, details={'was_impossible': False}),
#  Prediction(uid='A2KY73S2RZRJJ8', iid='B000001OMI', r_ui=5.0, est=4.094527874878158, details={'was_impossible': False}),
#  Prediction(uid='A21PE03OMHEPDJ', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3RVCVTQB8C3C1', iid='B00001W0DI', r_ui=5.0, est=4.417060027128199, details={'was_impossible': False}),
#  Prediction(uid='A3SRYSRYCQUROQ', iid='B00004T8R2', r_ui=4.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A1CIDLC8N28GLQ', iid='B00001W0DH', r_ui=4.0, est=4.110985964106741, details={'was_impossible': False}),
#  Prediction(uid='A2IOX5K9HITC3M', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2TCQYG3IZSLQ9', iid='B00001P4ZR', r_ui=5.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A2G4GS9EVCN3D2', iid='3744295508', r_ui=4.0, est=4.553782412695772, details={'was_impossible': False}),
#  Prediction(uid='A1WHALJO05OFDB', iid='B00004TDL2', r_ui=2.0, est=4.2267879632275855, details={'was_impossible': False}),
#  Prediction(uid='A2P6IHWVW8TSNM', iid='9575871979', r_ui=5.0, est=3.811263539024211, details={'was_impossible': False}),
#  Prediction(uid='A1YF660T3COD0X', iid='B00004SABB', r_ui=4.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AZEYC27CEA8RE', iid='B00001P4XH', r_ui=5.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A3TYDUWO6PKID6', iid='B000001OM5', r_ui=5.0, est=3.804225173218894, details={'was_impossible': False}),
#  Prediction(uid='A1T7TGDFADVX6Q', iid='B00000K13L', r_ui=3.0, est=4.564104560708621, details={'was_impossible': False}),
#  Prediction(uid='A21MW720EWZEM8', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2EUYMC77INP1M', iid='B00001OXQ9', r_ui=5.0, est=4.338158102379127, details={'was_impossible': False}),
#  Prediction(uid='A2PD18HFEHSOGB', iid='7214047977', r_ui=5.0, est=4.420866469354178, details={'was_impossible': False}),
#  Prediction(uid='A1C09WR0U11QY5', iid='B00001P4ZH', r_ui=1.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1GKE609LR26EP', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3MTCVR679YSON', iid='B00000J1UQ', r_ui=5.0, est=4.539862596250112, details={'was_impossible': False}),
#  Prediction(uid='A2NFD9HP2K6VRW', iid='B00004SABJ', r_ui=1.0, est=3.672616268701068, details={'was_impossible': False}),
#  Prediction(uid='A2F1I2W0VXUH9G', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A13HUHXEQPX3YI', iid='1400599997', r_ui=5.0, est=3.407147537853531, details={'was_impossible': False}),
#  Prediction(uid='A8N0LDIO7TDCO', iid='B00000J3UJ', r_ui=2.0, est=2.450531784502118, details={'was_impossible': False}),
#  Prediction(uid='A27SU24SXEDIPM', iid='B00000J061', r_ui=2.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='AK3VALQTT1EWO', iid='B00000JBAT', r_ui=1.0, est=3.6644301988924832, details={'was_impossible': False}),
#  Prediction(uid='A2HM5WYF0ZT86O', iid='B00000K2YR', r_ui=5.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A4PMK0JY7PHP0', iid='B00003ETSJ', r_ui=5.0, est=3.874494172300872, details={'was_impossible': False}),
#  Prediction(uid='A3BSE70YMG6FM0', iid='B000023VW2', r_ui=5.0, est=3.9730875573406315, details={'was_impossible': False}),
#  Prediction(uid='AKN5TK4AGENBF', iid='B00000J1SC', r_ui=4.0, est=4.100258217334701, details={'was_impossible': False}),
#  Prediction(uid='A1CJIT7DV4BTSN', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3L61G6N7AT8N2', iid='B00000J1TX', r_ui=2.0, est=4.307202036886721, details={'was_impossible': False}),
#  Prediction(uid='A3ZCIEUX68DEZ', iid='1400532620', r_ui=5.0, est=3.6307551899140007, details={'was_impossible': False}),
#  Prediction(uid='AN8W0XP8GCN1O', iid='B00002NDRQ', r_ui=4.0, est=4.60828299320297, details={'was_impossible': False}),
#  Prediction(uid='A2DXP6GLZNLUV0', iid='B00001ZWXA', r_ui=1.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A3P2JIBKDF4FZV', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='AUOSBAMC72RL9', iid='B00000JHWX', r_ui=3.0, est=4.208066842585875, details={'was_impossible': False}),
#  Prediction(uid='A2IBDTAQUO9UI8', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3K7QTMDO872EC', iid='B00004RDL5', r_ui=5.0, est=3.965251109075471, details={'was_impossible': False}),
#  Prediction(uid='AHQEZONRQERW2', iid='B00004R8VC', r_ui=3.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='AORFYDCA9MRCO', iid='B000031KIM', r_ui=4.0, est=4.196168143434032, details={'was_impossible': False}),
#  Prediction(uid='A1BBVETQXNPE88', iid='9983891212', r_ui=5.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='AZVL57D2NG3T1', iid='B00000K135', r_ui=4.0, est=4.566526471243159, details={'was_impossible': False}),
#  Prediction(uid='ACT1EPHFS9E7V', iid='B00000K135', r_ui=5.0, est=4.566526471243159, details={'was_impossible': False}),
#  Prediction(uid='A217IUGGD3JE45', iid='B00000JMUG', r_ui=4.0, est=3.53078948242854, details={'was_impossible': False}),
#  Prediction(uid='A4FKUX0RRJ699', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A3NWJ3AL0IZ8V1', iid='B00001P4ZH', r_ui=1.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3UNGIF5G9RMCN', iid='B00004TBLW', r_ui=5.0, est=4.317145628298537, details={'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B00000K135', r_ui=5.0, est=4.566526471243159, details={'was_impossible': False}),
#  Prediction(uid='AQ30S8GXHOHQC', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A1Y6N4X8FV6IAC', iid='B000001ON6', r_ui=5.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='A7LVTP7N6Q9Q1', iid='B00003006R', r_ui=4.0, est=3.7875140332929624, details={'was_impossible': False}),
#  Prediction(uid='A2LZ0ODVYL94VV', iid='B00004SABJ', r_ui=1.0, est=3.672616268701068, details={'was_impossible': False}),
#  Prediction(uid='AWEXS2INCGM73', iid='B00000J434', r_ui=1.0, est=3.608227842812174, details={'was_impossible': False}),
#  Prediction(uid='ANANVXGOAPKX3', iid='B00000JFIF', r_ui=4.0, est=4.38974517567974, details={'was_impossible': False}),
#  Prediction(uid='A3UGCKULLHJ01E', iid='B00003006K', r_ui=5.0, est=4.283890183118284, details={'was_impossible': False}),
#  Prediction(uid='A191NJZQ8I9QOD', iid='B00004SB92', r_ui=3.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A2DGUUI336IOPT', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A313RS3V8VECY3', iid='B00000JD34', r_ui=5.0, est=3.9442921614009085, details={'was_impossible': False}),
#  Prediction(uid='A9E0AWU3494WC', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='AJYOGRY24VT0S', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A32KVP3LIJLAQG', iid='B00004RG6K', r_ui=5.0, est=3.9760580311581846, details={'was_impossible': False}),
#  Prediction(uid='A149RNR5RH19YY', iid='B00001P4ZH', r_ui=5.0, est=4.466236457585094, details={'was_impossible': False}),
#  Prediction(uid='A2XVTCY5PHRLC4', iid='B00004TBLW', r_ui=3.0, est=4.317145628298537, details={'was_impossible': False}),
#  Prediction(uid='A1714OHZ7A94R', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2JWI6UY1OGKD8', iid='B00003WGP5', r_ui=5.0, est=4.250944099281516, details={'was_impossible': False}),
#  Prediction(uid='A25L15WOBSZJLP', iid='B00004R8VC', r_ui=5.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='AVK06OKY55S6H', iid='B00001WRSJ', r_ui=4.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A50ARWTXJ9FPV', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A2TWU5NQEJI5EV', iid='B00004TENT', r_ui=5.0, est=4.713563932460835, details={'was_impossible': False}),
#  Prediction(uid='A3U68T414KOKD2', iid='140053271X', r_ui=5.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A2EORZSMHG45DB', iid='9983891212', r_ui=5.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='A334X69Y2AJHJ6', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A3FINBR4T5ACH3', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A22Y2BYBKFXGMW', iid='B00004LMEC', r_ui=1.0, est=4.146709596193897, details={'was_impossible': False}),
#  Prediction(uid='A2KDJPCQWT6FF', iid='B00000JBAT', r_ui=5.0, est=3.6644301988924832, details={'was_impossible': False}),
#  Prediction(uid='A2HCBZSFA62MDO', iid='B00000J4FS', r_ui=5.0, est=3.9664069885343927, details={'was_impossible': False}),
#  Prediction(uid='A2JRNEPZPAHRUP', iid='1400532655', r_ui=1.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A2V69PY52MG7PO', iid='B00000JI4F', r_ui=4.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A1JMNGEXQ4HCD1', iid='B00001P4ZR', r_ui=3.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A2XKSCMIW8AZT2', iid='B00000J061', r_ui=4.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A1EG8MITQHGX2V', iid='B00004T1XE', r_ui=4.0, est=4.180822297521131, details={'was_impossible': False}),
#  Prediction(uid='A2FY4A86W9E31S', iid='B00003CWDH', r_ui=5.0, est=4.404500465144036, details={'was_impossible': False}),
#  Prediction(uid='A33U0ZEBYOJ3XH', iid='B00004RG6K', r_ui=4.0, est=3.9760580311581846, details={'was_impossible': False}),
#  Prediction(uid='A1LJT81FZW1HPL', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='AC9F4EXMZZUJE', iid='B00004TDN2', r_ui=5.0, est=4.213071244763905, details={'was_impossible': False}),
#  Prediction(uid='A2RULKDI00UF1F', iid='B00000J1V5', r_ui=5.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A2N8BXQ2BAYQNC', iid='B000001ON6', r_ui=5.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='A38D94CQEZBE1I', iid='B00000JI4F', r_ui=4.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A1IBF2BQTDHAD2', iid='B000028F42', r_ui=5.0, est=2.9991346799523053, details={'was_impossible': False}),
#  Prediction(uid='A19NI7EG704QLJ', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A2S2PG1LKF4YCX', iid='B00000J1V5', r_ui=5.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='AR0BDSQ7PDJX', iid='B00004TDLD', r_ui=5.0, est=4.819801589484264, details={'was_impossible': False}),
#  Prediction(uid='A2909VBH8409LU', iid='B00001P4XH', r_ui=4.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='ADS4GVLF8HIFU', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='AP4J7XNKV3TWW', iid='B00004TDMX', r_ui=5.0, est=3.828819660516503, details={'was_impossible': False}),
#  Prediction(uid='AROAG742G5QQV', iid='B00003006K', r_ui=5.0, est=4.283890183118284, details={'was_impossible': False}),
#  Prediction(uid='AN4S38NUQHNN0', iid='B00004SB92', r_ui=2.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A3BZHCZOVT3HG8', iid='B00000K4KH', r_ui=4.0, est=4.184129256717704, details={'was_impossible': False}),
#  Prediction(uid='A26AY8M7VU463O', iid='1400501466', r_ui=5.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='A1G3GKHX5237AU', iid='B00001WRSJ', r_ui=4.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2582KMXLK2P06', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='ALBMCTFT326N', iid='B00000J1EP', r_ui=5.0, est=4.671170506339994, details={'was_impossible': False}),
#  Prediction(uid='AK0A6283E5XZE', iid='B00002N7FQ', r_ui=5.0, est=4.343461500112672, details={'was_impossible': False}),
#  Prediction(uid='A3RXWKPFSXZVGW', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2I1VGMT4Z7H6W', iid='B00004SABB', r_ui=3.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AEFMP9SZ33XXA', iid='B00000J08Q', r_ui=1.0, est=2.663262562610353, details={'was_impossible': False}),
#  Prediction(uid='A189CUZKO895GV', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A1VYNYUM57GAM0', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A2DCA4ZXU8Z3W6', iid='B00000J061', r_ui=5.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A18EDD2THNK1Y9', iid='B00000J4FS', r_ui=5.0, est=3.9664069885343927, details={'was_impossible': False}),
#  Prediction(uid='A2EPG51IWPIE5E', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2SU8JOOZXUA98', iid='B00004SABB', r_ui=4.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A23XH0IU02M6AF', iid='B00001P4XA', r_ui=2.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A2UGPULXMCJNFK', iid='B00001P4XA', r_ui=1.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A1JLOY9EN2FXIK', iid='B00000JDF5', r_ui=1.0, est=4.576588335518408, details={'was_impossible': False}),
#  Prediction(uid='AO8KSXICXE407', iid='B00000J1F3', r_ui=5.0, est=3.969709085145472, details={'was_impossible': False}),
#  Prediction(uid='A3CWNB8E2ENS49', iid='B00001P4ZR', r_ui=1.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A84QRMCQNJCTI', iid='B000001ON6', r_ui=5.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='AA21JHE6KOC4W', iid='B00002NDRQ', r_ui=4.0, est=4.60828299320297, details={'was_impossible': False}),
#  Prediction(uid='A1TFV97Y3OP5HT', iid='B00003CWDG', r_ui=4.0, est=4.176059917351874, details={'was_impossible': False}),
#  Prediction(uid='A20MNJUKVXBAEY', iid='B00004SB92', r_ui=2.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='ACPQTJE7LY531', iid='B00004SABJ', r_ui=3.0, est=3.672616268701068, details={'was_impossible': False}),
#  Prediction(uid='A1O0UVMW53FC20', iid='B00004R8VC', r_ui=4.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='A3NBB6GVY787J3', iid='B00004S9AK', r_ui=5.0, est=4.300347175606129, details={'was_impossible': False}),
#  Prediction(uid='AVL70UM8UXA3L', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A3VBHFEVQB88MJ', iid='B00001P4ZR', r_ui=5.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A19SDATK4UWAIQ', iid='B00000JFE3', r_ui=5.0, est=3.3546426577870623, details={'was_impossible': False}),
#  Prediction(uid='A341590851VY75', iid='B00000JSGF', r_ui=2.0, est=3.9836250991699536, details={'was_impossible': False}),
#  Prediction(uid='A3RNAIFV56WG5E', iid='B00000J061', r_ui=5.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A23FKOXQHBR89R', iid='B00000J1V5', r_ui=4.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A1TT167N28J95A', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A1ACUIN0UZC4K4', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A4J496S0ASF2I', iid='B00001ZT4H', r_ui=4.0, est=4.178011151599929, details={'was_impossible': False}),
#  Prediction(uid='A36V8NDDRZYRYO', iid='1400532655', r_ui=1.0, est=3.392834213208132, details={'was_impossible': False}),
#  Prediction(uid='A15CETA23DVNCW', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2300XBCSPBPVO', iid='B00000JI4F', r_ui=5.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A3QJFOLL5KGS8H', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='ATTXHB1QLSYC3', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A3UWM2JGOASDI4', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A3604P2WLEGX9U', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A2V84I2M1DT1TZ', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2J0JEVCINT7IY', iid='B00000JI4F', r_ui=5.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A1248WEQ66LYM6', iid='B00001P4ZH', r_ui=1.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1CWJIHXZJB0XU', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='AJB5USN0DZKQ1', iid='B00000K2YR', r_ui=5.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A2YG0C7JIOSZZ2', iid='B00001WRSJ', r_ui=3.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A3QFGTQH5QQ60A', iid='B00004RG6K', r_ui=3.0, est=3.9760580311581846, details={'was_impossible': False}),
#  Prediction(uid='AJZRG0DTIQP2Y', iid='B00000JD34', r_ui=3.0, est=3.9442921614009085, details={'was_impossible': False}),
#  Prediction(uid='A235GYTC4268T2', iid='B00001P4ZR', r_ui=5.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A13SZHBTLJU0KI', iid='1400599997', r_ui=1.0, est=3.407147537853531, details={'was_impossible': False}),
#  Prediction(uid='A3ARPUKCI6R91Y', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A3FTI86WAVJOLG', iid='B00000JSGF', r_ui=1.0, est=4.143017175945211, details={'was_impossible': False}),
#  Prediction(uid='A3TH5MG8Y387U1', iid='B00000K13L', r_ui=5.0, est=4.564104560708621, details={'was_impossible': False}),
#  Prediction(uid='A3G8PHTYONNTQM', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A6IESZPQH9LZ5', iid='B00001P4ZH', r_ui=1.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1MGS94AG7NSZL', iid='9625993428', r_ui=5.0, est=3.407455099976705, details={'was_impossible': False}),
#  Prediction(uid='A2S1QTQDC40B13', iid='B00004RC2D', r_ui=5.0, est=4.37887066449998, details={'was_impossible': False}),
#  Prediction(uid='A3TF6PPEYAQ1KX', iid='0972683275', r_ui=4.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A3UT75Z4PPGTS2', iid='B00004TEN2', r_ui=5.0, est=3.7932373013252265, details={'was_impossible': False}),
#  Prediction(uid='A56VVV7KW2IS6', iid='B00002NDRQ', r_ui=4.0, est=4.60828299320297, details={'was_impossible': False}),
#  Prediction(uid='AZICZ21T0UQT', iid='B00000JBHP', r_ui=3.0, est=4.168263438154425, details={'was_impossible': False}),
#  Prediction(uid='AJ6733H9C0V9O', iid='B0000222MY', r_ui=4.0, est=3.773431221225707, details={'was_impossible': False}),
#  Prediction(uid='A291SZH92OHH8P', iid='B00002ST80', r_ui=4.0, est=3.9764744324653307, details={'was_impossible': False}),
#  Prediction(uid='A1JVWSW606CBIK', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A1SKOP77DH7TEP', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A310EQW2G09TAN', iid='1400532655', r_ui=4.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A1F7XETXDDGRBE', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A3PLRSXI9WLF97', iid='B00004SPUN', r_ui=1.0, est=3.241027986476379, details={'was_impossible': False}),
#  Prediction(uid='AEOGQGQZ0SMLQ', iid='1400501466', r_ui=5.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='AO6IXF7J8IWZN', iid='1400501466', r_ui=2.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='A3EQQHWJ1EEYEU', iid='B00004SABB', r_ui=5.0, est=4.048681286860242, details={'was_impossible': False}),
#  Prediction(uid='AMEGPD597TRUN', iid='B000028F42', r_ui=5.0, est=2.9991346799523053, details={'was_impossible': False}),
#  Prediction(uid='AF3SKP1L6HPXC', iid='B00003ETSJ', r_ui=1.0, est=3.860584764799247, details={'was_impossible': False}),
#  Prediction(uid='A1XMBES5H742JH', iid='B00004R8VC', r_ui=5.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='A343Y6JLIXAEAH', iid='1400501466', r_ui=2.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='A4U8NV8P13RH9', iid='B00000JDF5', r_ui=5.0, est=4.576588335518408, details={'was_impossible': False}),
#  Prediction(uid='A1MZVETF38AMZ6', iid='1400501776', r_ui=3.0, est=3.864718080866799, details={'was_impossible': False}),
#  Prediction(uid='A38PLWYVUL3OPM', iid='B00000J3UJ', r_ui=5.0, est=2.450531784502118, details={'was_impossible': False}),
#  Prediction(uid='A38OVSLH125IAX', iid='B0000228GF', r_ui=2.0, est=3.592140498244497, details={'was_impossible': False}),
#  Prediction(uid='A2G8B0817XH8XG', iid='B00001P4XA', r_ui=5.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A1TYTLET80FO1T', iid='B00000J05A', r_ui=5.0, est=3.2546039604189847, details={'was_impossible': False}),
#  Prediction(uid='A1W2032TPJH057', iid='B00000J1EQ', r_ui=1.0, est=4.159199171733841, details={'was_impossible': False}),
#  Prediction(uid='A2GJU27367VVCX', iid='B00000JI4F', r_ui=5.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A39708HO9ZHZT', iid='B00001P4ZR', r_ui=4.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A25GSHB6XB8BY', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1TN2BHF8DNJF3', iid='B00000JCTO', r_ui=1.0, est=3.4570162822958705, details={'was_impossible': False}),
#  Prediction(uid='A19HKRB4LU5YR', iid='B00000J1U8', r_ui=5.0, est=4.440438877829541, details={'was_impossible': False}),
#  Prediction(uid='A2GXF005NS68CI', iid='9575871979', r_ui=5.0, est=3.811263539024211, details={'was_impossible': False}),
#  Prediction(uid='A1WXVSVPU23QST', iid='B00003CWDG', r_ui=4.0, est=4.176059917351874, details={'was_impossible': False}),
#  Prediction(uid='AO4UKTEK9UER6', iid='B00001QEMF', r_ui=5.0, est=4.476000262708626, details={'was_impossible': False}),
#  Prediction(uid='A16KCYJ17GYMQV', iid='B00001W0EQ', r_ui=1.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='AK0D6HY8FZILU', iid='B00004T1XK', r_ui=5.0, est=4.155670715236997, details={'was_impossible': False}),
#  Prediction(uid='A11V13PTQQATDY', iid='B00001P4XA', r_ui=5.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A1V0E3ITYVCFPJ', iid='B000038ABH', r_ui=4.0, est=4.266984670988946, details={'was_impossible': False}),
#  Prediction(uid='A3M1JZGUOQHSPE', iid='B00001P4XA', r_ui=4.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='APJXF6Z4Z61YW', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3TJZCS3EC4R8E', iid='1400532736', r_ui=3.0, est=3.8184660589737724, details={'was_impossible': False}),
#  Prediction(uid='A2S7QXRE1R9NFM', iid='9966694544', r_ui=5.0, est=3.9567555592448858, details={'was_impossible': False}),
#  Prediction(uid='A1RRO3BUQIZ8QF', iid='B000026D8E', r_ui=5.0, est=3.145694415354138, details={'was_impossible': False}),
#  Prediction(uid='A2XDR23OZM6W7Z', iid='B00004SABB', r_ui=4.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A2GCUTSKDQ1PL5', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='AT8YWJ9SEL4T8', iid='B00004SB92', r_ui=4.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A11JDD2KZVUOT6', iid='B00000J4GE', r_ui=5.0, est=3.908677937839672, details={'was_impossible': False}),
#  Prediction(uid='AMQTIM33ZRMD2', iid='B00004SABB', r_ui=3.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AYMLP6MELRYYN', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A3JO155KF3379B', iid='B00001WRSJ', r_ui=3.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='AIGWPQJOMYZAL', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A2QHOPALSQMP10', iid='B00001W0DG', r_ui=3.0, est=3.6216854442368565, details={'was_impossible': False}),
#  Prediction(uid='A2NOK0N8OMNJYZ', iid='B00004TEN2', r_ui=5.0, est=3.7932373013252265, details={'was_impossible': False}),
#  Prediction(uid='A3SLUJOV6PEWXH', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A21ID5MCWN9E87', iid='B00001P4ZH', r_ui=4.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='AACB6ENIDO0ND', iid='B00004TDSC', r_ui=1.0, est=4.1324243157930285, details={'was_impossible': False}),
#  Prediction(uid='A1463ASM7QMU2I', iid='0972683275', r_ui=3.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A3DL67RLSWPJ15', iid='B00004SB92', r_ui=5.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A9LRAZ5B8377G', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='AGH2XYTGXDSMW', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A6SAC9YD4MI1W', iid='B000023VW2', r_ui=4.0, est=3.9730875573406315, details={'was_impossible': False}),
#  Prediction(uid='AMEKP32Q9TYNU', iid='B00001P4XH', r_ui=1.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A314YGGISZRUUA', iid='1400599997', r_ui=4.0, est=3.407147537853531, details={'was_impossible': False}),
#  Prediction(uid='A2K71J7YK6K91A', iid='B00004SABJ', r_ui=4.0, est=3.672616268701068, details={'was_impossible': False}),
#  Prediction(uid='ADWUJZ8865J2A', iid='B00000J1V5', r_ui=5.0, est=4.692405923082285, details={'was_impossible': False}),
#  Prediction(uid='AYA1LQR98Y181', iid='B00001P4ZR', r_ui=3.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A2PZ5GNIO1BE2O', iid='B00004RC2D', r_ui=5.0, est=4.529287905037139, details={'was_impossible': False}),
#  Prediction(uid='A2Y1X1YP6L6ZGS', iid='B00004SB92', r_ui=5.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A2RZY68AP11NOS', iid='B00004T8R2', r_ui=3.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2SLR2VUDUGCQM', iid='B00004TDLD', r_ui=5.0, est=4.819801589484264, details={'was_impossible': False}),
#  Prediction(uid='AV6B7RWZ7ZFAC', iid='B00001U0AJ', r_ui=1.0, est=3.081902889529575, details={'was_impossible': False}),
#  Prediction(uid='AN560AP1HH0U1', iid='B00000K135', r_ui=5.0, est=4.5523626822648735, details={'was_impossible': False}),
#  Prediction(uid='A2W1WSEK68UXJX', iid='1400532736', r_ui=5.0, est=3.8184660589737724, details={'was_impossible': False}),
#  Prediction(uid='A2928DGP0TB6SJ', iid='B00000J061', r_ui=2.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='ANBDKFVX16VAR', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='AZRR55GM4Y9NK', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A39VM0VY5M1LYP', iid='B00000JI4F', r_ui=5.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A22870XFVVBHIJ', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='AC44NOLB5JDSW', iid='B00001P4XH', r_ui=5.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A3HKWR763KC1MX', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='AL392W87HB0OM', iid='9983891212', r_ui=5.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='A1GE6AROZ4IEAJ', iid='B00000K2YR', r_ui=4.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A3RZX5KZX4HYG6', iid='B00002EQCS', r_ui=2.0, est=4.4992508628488705, details={'was_impossible': False}),
#  Prediction(uid='A2ZHYB5Z0F1MKU', iid='B00000K2YR', r_ui=4.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A2L3OAPBMBGHHD', iid='9984984354', r_ui=5.0, est=3.0550667705063232, details={'was_impossible': False}),
#  Prediction(uid='AY3CFYO5RZI7D', iid='B00000J1V3', r_ui=1.0, est=4.43127916860495, details={'was_impossible': False}),
#  Prediction(uid='AAEVGE52KL0DJ', iid='9575871979', r_ui=3.0, est=3.811263539024211, details={'was_impossible': False}),
#  Prediction(uid='A2W5W7PGLF2O2J', iid='B00000J08Q', r_ui=4.0, est=2.663262562610353, details={'was_impossible': False}),
#  Prediction(uid='A3BSR1TPMAXW3T', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A1YK0A2FB2XW5Z', iid='B00004SPUN', r_ui=2.0, est=3.241027986476379, details={'was_impossible': False}),
#  Prediction(uid='A2Q5WQXFRN46IF', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A2W3CVBKM239H5', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A2E09FNX574MX2', iid='B00004T8R2', r_ui=4.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A1EA08F54PPH4O', iid='B00000DM9W', r_ui=4.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A2YJG317V45G33', iid='B00004R8VC', r_ui=5.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='A1DYJMKWDD1ASW', iid='1400698987', r_ui=5.0, est=4.288684006851187, details={'was_impossible': False}),
#  Prediction(uid='A1KVBDXAIHPBZW', iid='1400599997', r_ui=5.0, est=3.407147537853531, details={'was_impossible': False}),
#  Prediction(uid='ASHVC731YAJK4', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2IR9680RV5O5J', iid='B00004T8R2', r_ui=3.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2FXX9VTD10J6C', iid='B00001WRSJ', r_ui=4.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='ABTTTO2097OSZ', iid='B00004TEN2', r_ui=4.0, est=3.7932373013252265, details={'was_impossible': False}),
#  Prediction(uid='ATIESTXNUFNSW', iid='B00000K2YR', r_ui=3.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A3UW5S1SF8TR7C', iid='B00000J1QK', r_ui=5.0, est=3.8569593203728814, details={'was_impossible': False}),
#  Prediction(uid='AWBUA3QUM6DRY', iid='B000021YU8', r_ui=4.0, est=4.576327495971343, details={'was_impossible': False}),
#  Prediction(uid='A2R9RFYVH8JA4V', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A3AOURGFCO8VA4', iid='B000031KIM', r_ui=1.0, est=4.196168143434032, details={'was_impossible': False}),
#  Prediction(uid='A1W7L2UB26HF80', iid='B00000JPPI', r_ui=4.0, est=3.6621243005256914, details={'was_impossible': False}),
#  Prediction(uid='A1O12N9LEZLWGU', iid='B00004T1XE', r_ui=3.0, est=4.180822297521131, details={'was_impossible': False}),
#  Prediction(uid='A4MLBRTM4OH15', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A13890JC4T33YJ', iid='B00001P4ZH', r_ui=4.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='AE38XXG3CPZ0L', iid='B00000J1UQ', r_ui=5.0, est=4.539862596250112, details={'was_impossible': False}),
#  Prediction(uid='A1PH5UQOF0BMTL', iid='B00000J061', r_ui=5.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A3J8A5L5AF5TX9', iid='B00001P4XA', r_ui=4.0, est=3.847965187331553, details={'was_impossible': False}),
#  Prediction(uid='A1KHK063A1XPDM', iid='B0000222MY', r_ui=4.0, est=3.8286315160188225, details={'was_impossible': False}),
#  Prediction(uid='A24AGAOVQ9V1AT', iid='B00000J1TX', r_ui=5.0, est=4.307202036886721, details={'was_impossible': False}),
#  Prediction(uid='AA7EKIPVXU542', iid='B00000JCT8', r_ui=1.0, est=3.486216957126412, details={'was_impossible': False}),
#  Prediction(uid='A2OVNQFVEPN8GE', iid='B00000JBHP', r_ui=5.0, est=4.168263438154425, details={'was_impossible': False}),
#  Prediction(uid='A2V7UA8F2FV3K3', iid='B00001W0DI', r_ui=5.0, est=4.417060027128199, details={'was_impossible': False}),
#  Prediction(uid='A2J88YVI0QCZOC', iid='B00001P4ZR', r_ui=3.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='AOLC9OV244MFW', iid='B00004SABB', r_ui=2.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A3RS2VSXYYHUM0', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A1U1Q4SO0C4B0T', iid='1400532736', r_ui=5.0, est=3.8184660589737724, details={'was_impossible': False}),
#  Prediction(uid='A2XJD20SEKWFCK', iid='B00000J1EJ', r_ui=3.0, est=3.1507313271319846, details={'was_impossible': False}),
#  Prediction(uid='A3S6STORWL74JY', iid='B00004TDL2', r_ui=5.0, est=4.2267879632275855, details={'was_impossible': False}),
#  Prediction(uid='ACLX31SIC7BG2', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2K5FK58JSWXJ9', iid='B00004RC2D', r_ui=4.0, est=4.596870638272681, details={'was_impossible': False}),
#  Prediction(uid='A2T43NVBPTLJIN', iid='B00004SABB', r_ui=5.0, est=3.943881535397315, details={'was_impossible': False}),
#  Prediction(uid='A3KKYNEYUICKX2', iid='B00004SB92', r_ui=1.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A3I9QEZ1YRC2QL', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2DTXMVW1EQEW2', iid='B00004SB92', r_ui=3.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='ADOR3TR7GDF68', iid='B00003CWDH', r_ui=3.0, est=4.18879083643489, details={'was_impossible': False}),
#  Prediction(uid='A30ISDN6ZV58L4', iid='B00001W0EQ', r_ui=2.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A1DGED31BJ7H4D', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A2WQNHK82VTJWT', iid='B00002JXFH', r_ui=4.0, est=4.346478570455973, details={'was_impossible': False}),
#  Prediction(uid='A1MIVLLRVY1T51', iid='B00004TDLD', r_ui=5.0, est=4.819801589484264, details={'was_impossible': False}),
#  Prediction(uid='A1KFG02FY7NS0T', iid='B00003ETSJ', r_ui=5.0, est=3.874494172300872, details={'was_impossible': False}),
#  Prediction(uid='A28WMDWA2RVC9G', iid='B00000K2YR', r_ui=5.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A25AFGKYE2EHGX', iid='B00001W0EQ', r_ui=3.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='ANWG5QOMYBSDB', iid='B00004RC2D', r_ui=5.0, est=4.37887066449998, details={'was_impossible': False}),
#  Prediction(uid='A3U2NVZ94D5232', iid='7214047977', r_ui=5.0, est=4.420866469354178, details={'was_impossible': False}),
#  Prediction(uid='A23VVQOCBLUIFG', iid='B00001P505', r_ui=5.0, est=4.192837475526016, details={'was_impossible': False}),
#  Prediction(uid='A1V6TV1212TE1P', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='ATI491ZHUTVNF', iid='B00001OPJZ', r_ui=1.0, est=4.127592238247181, details={'was_impossible': False}),
#  Prediction(uid='A3B10LNQ62E4TN', iid='B00001WRSJ', r_ui=3.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2F1JXRGKY7TBF', iid='B00000J3UJ', r_ui=1.0, est=2.450531784502118, details={'was_impossible': False}),
#  Prediction(uid='AOYKD7G6QJ52K', iid='B00004T8R2', r_ui=4.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='AM5YLOL7NJLZV', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A30VNSE9F8QPE6', iid='B00004T8R2', r_ui=4.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A37O3PHY4QWG47', iid='B000001OM4', r_ui=5.0, est=3.630712505734079, details={'was_impossible': False}),
#  Prediction(uid='A22FLUSSE5ECK2', iid='B0000228GF', r_ui=4.0, est=3.592140498244497, details={'was_impossible': False}),
#  Prediction(uid='A3SL60WWXFOFLC', iid='1400501466', r_ui=1.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='A22RW51298Z15M', iid='B00003CWDH', r_ui=5.0, est=4.404500465144036, details={'was_impossible': False}),
#  Prediction(uid='A2W48L5D44LAQ8', iid='B00004T1XK', r_ui=3.0, est=4.155670715236997, details={'was_impossible': False}),
#  Prediction(uid='A1AIZEN4GRI1QY', iid='B00000J061', r_ui=5.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A3F1B6K0MQ9X06', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A3GZQJZLSMETLI', iid='B00000K135', r_ui=5.0, est=4.600056889650188, details={'was_impossible': False}),
#  Prediction(uid='A2IE2U4SL7JWX2', iid='B00000J1SC', r_ui=5.0, est=4.100258217334701, details={'was_impossible': False}),
#  Prediction(uid='A3CJFSCTJZX567', iid='B00000JFIF', r_ui=1.0, est=4.38974517567974, details={'was_impossible': False}),
#  Prediction(uid='A1DIUCRG3B01GI', iid='B00000J1SC', r_ui=5.0, est=4.100258217334701, details={'was_impossible': False}),
#  Prediction(uid='A1CMQZPKXH2QXO', iid='9625993428', r_ui=3.0, est=3.407455099976705, details={'was_impossible': False}),
#  Prediction(uid='A3NCC9U3CWOEM6', iid='B00004T0RC', r_ui=5.0, est=4.417471069245022, details={'was_impossible': False}),
#  Prediction(uid='AVE2J7PNE0L9C', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A1TDHAKEDTJL2J', iid='B00002EQCW', r_ui=4.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A17TUQPO34BNTP', iid='B00004SB92', r_ui=5.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A3479FS9K87E6O', iid='B00001P4XA', r_ui=1.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='AB76THS0IXKAQ', iid='B000026D8E', r_ui=1.0, est=3.145694415354138, details={'was_impossible': False}),
#  Prediction(uid='A38K49W2LZN7QA', iid='B00003CWDK', r_ui=4.0, est=4.36731792277443, details={'was_impossible': False}),
#  Prediction(uid='A3QZUUZDBIB9DD', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AOKUJ3LLW5TSS', iid='B00001OWYM', r_ui=1.0, est=3.2526195146212795, details={'was_impossible': False}),
#  Prediction(uid='A1RL716SZFSCZ6', iid='B00004R8VC', r_ui=5.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='A1XTQULERNAFQ', iid='1400698987', r_ui=5.0, est=4.288684006851187, details={'was_impossible': False}),
#  Prediction(uid='A2WJTAQ2RTDFE0', iid='B00004T1XK', r_ui=1.0, est=4.155670715236997, details={'was_impossible': False}),
#  Prediction(uid='A22VVNXSWCMHNB', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A1M292J992EFOF', iid='B00001P4XA', r_ui=1.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A81BDLL58OE00', iid='B00004SABB', r_ui=3.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A3QEPLR68VG0CV', iid='B00000K13A', r_ui=4.0, est=4.486896625589267, details={'was_impossible': False}),
#  Prediction(uid='A1YG5RLEAXEE5E', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A27UCPERS7GFBI', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A3H8R9RBN7MYD', iid='B00000K4KH', r_ui=4.0, est=4.184129256717704, details={'was_impossible': False}),
#  Prediction(uid='ATU14DODLD45Q', iid='9984984354', r_ui=1.0, est=3.0550667705063232, details={'was_impossible': False}),
#  Prediction(uid='AKAHD3IF65A4B', iid='B00004SB92', r_ui=3.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='AB3KZDFAODJLI', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A2JMOFJZ854SJR', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A38VUSBYQZCKUQ', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A1NR52YKZSFI9D', iid='B00000K4KH', r_ui=5.0, est=4.184129256717704, details={'was_impossible': False}),
#  Prediction(uid='A2GTXA8FTBSRS9', iid='9573212919', r_ui=5.0, est=3.8339671536248083, details={'was_impossible': False}),
#  Prediction(uid='AWR89V8TLV1RY', iid='B00003006K', r_ui=5.0, est=4.283890183118284, details={'was_impossible': False}),
#  Prediction(uid='A2E16VJFLGWOVJ', iid='B00004TDMX', r_ui=5.0, est=3.828819660516503, details={'was_impossible': False}),
#  Prediction(uid='ALMVATCTH0QJ6', iid='B000021YUO', r_ui=5.0, est=4.213399844039273, details={'was_impossible': False}),
#  Prediction(uid='A3HE9I4GQ4OXYE', iid='B00000J05A', r_ui=1.0, est=3.33136203535127, details={'was_impossible': False}),
#  Prediction(uid='AXABTEYS7A4A8', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A2UGQS7KN3N1OB', iid='B00003006K', r_ui=1.0, est=4.283890183118284, details={'was_impossible': False}),
#  Prediction(uid='A34I5D2SBLN6BP', iid='B00004SABB', r_ui=3.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A329D7F2CPS1QF', iid='B00000K2YR', r_ui=5.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A3DDWOPNS26TPI', iid='B00004R8VC', r_ui=5.0, est=4.4818221685989, details={'was_impossible': False}),
#  Prediction(uid='A3VMCFOCPL3R7Q', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A10HMCB7K4HZYL', iid='1400532655', r_ui=1.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A28SWZVAJQF86W', iid='B00003WGP5', r_ui=1.0, est=4.250944099281516, details={'was_impossible': False}),
#  Prediction(uid='A1TBH7Z4RK7PRK', iid='B00000J061', r_ui=5.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='A1EZ520KVSUVST', iid='B00003CWDH', r_ui=5.0, est=4.404500465144036, details={'was_impossible': False}),
#  Prediction(uid='A11CH52DG6EF6P', iid='B00000K2YR', r_ui=1.0, est=4.0388397658959105, details={'was_impossible': False}),
#  Prediction(uid='A3S1QHA8SBF8HQ', iid='B00003006E', r_ui=5.0, est=4.321602540333662, details={'was_impossible': False}),
#  Prediction(uid='A2UN390U3YBZJE', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='A9I2WWVAZJ2ZP', iid='B00004T1XK', r_ui=5.0, est=4.155670715236997, details={'was_impossible': False}),
#  Prediction(uid='A12LBD1IJ8M99Y', iid='0972683275', r_ui=4.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A76K23HQ5M4C2', iid='9625993428', r_ui=5.0, est=3.407455099976705, details={'was_impossible': False}),
#  Prediction(uid='A24WJXSXVNB9KF', iid='B00001P4XH', r_ui=5.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A2IL3E3X9XM9O5', iid='1400532620', r_ui=1.0, est=3.6307551899140007, details={'was_impossible': False}),
#  Prediction(uid='A18Y78K7O60QI0', iid='B00000JFMK', r_ui=4.0, est=4.626832022823668, details={'was_impossible': False}),
#  Prediction(uid='AWBWAKGVPCC8W', iid='B00004R8V6', r_ui=5.0, est=4.479450817964392, details={'was_impossible': False}),
#  Prediction(uid='A1UXB02VECZ08U', iid='B00003CWDQ', r_ui=5.0, est=4.2144362706398955, details={'was_impossible': False}),
#  Prediction(uid='A1LA54IU9QKJWO', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A5SVSC31K3O01', iid='B00001P4ZR', r_ui=2.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='AGWOHX24U4VRQ', iid='B000001OMI', r_ui=4.0, est=4.094527874878158, details={'was_impossible': False}),
#  Prediction(uid='A3FY2U0WFQIEUP', iid='B00000J1F3', r_ui=1.0, est=3.969709085145472, details={'was_impossible': False}),
#  Prediction(uid='A1UFQPHYFJ0607', iid='B00004SABB', r_ui=4.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AO0HCM35LL15D', iid='B00004RC2D', r_ui=4.0, est=4.37887066449998, details={'was_impossible': False}),
#  Prediction(uid='A3I407F1T9WWSJ', iid='B00001ZWXA', r_ui=1.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B00001P4ZH', r_ui=4.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1S4YQVFG7LRKZ', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A2RELVDY2PSZHD', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A2CHLPRJZSD6U9', iid='B00004SY4H', r_ui=5.0, est=4.725937500037273, details={'was_impossible': False}),
# ...
#  Prediction(uid='A3LHB2WXB7T7C0', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A20UYWODMBPNVT', iid='B00001W0DI', r_ui=5.0, est=4.417060027128199, details={'was_impossible': False}),
#  Prediction(uid='A21IHH3ZKOG07U', iid='B00001P505', r_ui=5.0, est=4.304640573379718, details={'was_impossible': False}),
#  Prediction(uid='A2O8VPEZPNKEX7', iid='B00000K2YV', r_ui=1.0, est=3.213205576606357, details={'was_impossible': False}),
#  Prediction(uid='A16Q3CV7TCFO4E', iid='0972683275', r_ui=3.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='AVEUMSBNRA5TJ', iid='B00004SABB', r_ui=3.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A21D2DEK08ZXMJ', iid='B00001W0EQ', r_ui=1.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A3AFPQWM1RGSDE', iid='B00001W0EQ', r_ui=5.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A2I7KTCQGLOI50', iid='B00001P4ZR', r_ui=4.0, est=4.112386012837884, details={'was_impossible': False}),
#  Prediction(uid='A15HWCD31JSEEJ', iid='B00004TDL2', r_ui=1.0, est=4.2267879632275855, details={'was_impossible': False}),
#  Prediction(uid='A2E7IHO5DH3TG9', iid='B00000JMUG', r_ui=2.0, est=3.53078948242854, details={'was_impossible': False}),
#  Prediction(uid='A89AEU557A93H', iid='B00001W0EQ', r_ui=4.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A3SWF9UXQAEK9Q', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A304S6UPV1PWYJ', iid='B00003CWDG', r_ui=3.0, est=4.176059917351874, details={'was_impossible': False}),
#  Prediction(uid='AJGIN15VFGXBG', iid='140053271X', r_ui=1.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A1U4P7H8ZEDEQJ', iid='9983891212', r_ui=5.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='A3G2FBPWMEQARW', iid='B00004TBLW', r_ui=2.0, est=4.317145628298537, details={'was_impossible': False}),
#  Prediction(uid='AZP307PE3CIPC', iid='B00004SB92', r_ui=1.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A11RPOQC6QXNHR', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2XQW1K6ALWSMZ', iid='B00004TDLD', r_ui=5.0, est=4.819801589484264, details={'was_impossible': False}),
#  Prediction(uid='AMKLPT0TUQ9B4', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A14MH79OV61SR3', iid='1400501466', r_ui=1.0, est=3.5965432161246804, details={'was_impossible': False}),
#  Prediction(uid='A28CAQRAIZ1UWU', iid='B00000J1V5', r_ui=5.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A3FTI86WAVJOLG', iid='B00004TDN2', r_ui=5.0, est=4.372463321539162, details={'was_impossible': False}),
#  Prediction(uid='A1N73M40MPPWSR', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='AC0QKQRS4VULH', iid='B00004SABB', r_ui=5.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A2IG1X4LWAS2F4', iid='B00004RFB8', r_ui=3.0, est=2.246840572831596, details={'was_impossible': False}),
#  Prediction(uid='AT2AHVDUSFNJ7', iid='B00001P4ZH', r_ui=4.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A5X3DVSN6XRJ1', iid='140053271X', r_ui=3.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A2GIV4SHMBVX5I', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='AVA3OYU7GHAI8', iid='B00000J3NF', r_ui=4.0, est=4.675036400469794, details={'was_impossible': False}),
#  Prediction(uid='A1QTOSC4HKKOO1', iid='B00000JI4F', r_ui=5.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='AF7XQ8Q3N5Z7W', iid='B00004SABJ', r_ui=3.0, est=3.672616268701068, details={'was_impossible': False}),
#  Prediction(uid='A1C00XXCYWEKK1', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='AZZMV5VT9W7Y8', iid='1400501776', r_ui=1.0, est=3.864718080866799, details={'was_impossible': False}),
#  Prediction(uid='A1U7ZC83PQU982', iid='B00004TDSC', r_ui=5.0, est=4.1324243157930285, details={'was_impossible': False}),
#  Prediction(uid='AGK0AW19KX0Y9', iid='1400532655', r_ui=5.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A1PXYL03REYJPU', iid='B00004TENT', r_ui=4.0, est=4.713563932460835, details={'was_impossible': False}),
#  Prediction(uid='A2514AOC9T6RCS', iid='B00001P4ZH', r_ui=1.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2FV460ROVXXC9', iid='B00000J061', r_ui=4.0, est=4.176988679870965, details={'was_impossible': False}),
#  Prediction(uid='AOZJDHJ2UEBR6', iid='B000021YUO', r_ui=2.0, est=4.213399844039273, details={'was_impossible': False}),
#  Prediction(uid='A3VK2YVHWSVQHB', iid='B00004SPUN', r_ui=3.0, est=3.3177860614086643, details={'was_impossible': False}),
#  Prediction(uid='A1I43BAZ2MDJB1', iid='B00000J1V5', r_ui=4.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A1TUBWVAM693NU', iid='B00000JBAT', r_ui=5.0, est=3.6644301988924832, details={'was_impossible': False}),
#  Prediction(uid='A2P6FU1HQ1OFAP', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A2TA0DDRQU0C', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A1JZEPPYFZDRPC', iid='B00000K135', r_ui=5.0, est=4.566526471243159, details={'was_impossible': False}),
#  Prediction(uid='A2ED2S3APUJCWD', iid='B00001P505', r_ui=1.0, est=4.304640573379718, details={'was_impossible': False}),
#  Prediction(uid='A1CXLZ5Q8V59FT', iid='B00000J1EJ', r_ui=5.0, est=3.1507313271319846, details={'was_impossible': False}),
#  Prediction(uid='A26QCCO0101CO1', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A332GY091Q5QIK', iid='B00000J1SC', r_ui=2.0, est=4.100258217334701, details={'was_impossible': False}),
#  Prediction(uid='A1IS1QNHOQVMG5', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='AC258TGMAO51G', iid='B00001P4XH', r_ui=1.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A3OIOERIJCVPQS', iid='B00001WRSJ', r_ui=3.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2RMLJU43O2OQI', iid='B00004T8R2', r_ui=5.0, est=4.2679863504882345, details={'was_impossible': False}),
#  Prediction(uid='A47HWSPR8430B', iid='B00000JI4F', r_ui=4.0, est=3.8017081890500775, details={'was_impossible': False}),
#  Prediction(uid='A2MCUSEVM7SXBM', iid='B00001W0DH', r_ui=4.0, est=4.110985964106741, details={'was_impossible': False}),
#  Prediction(uid='AOOU4GVVQHK5O', iid='B00004SB92', r_ui=5.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A2H6D0718S7C3Y', iid='140053271X', r_ui=1.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A1Y8XK5286THYU', iid='1400532655', r_ui=1.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A2R7HO5NM4TB64', iid='B00004T1XK', r_ui=4.0, est=4.155670715236997, details={'was_impossible': False}),
#  Prediction(uid='ACISLJANCZZ6L', iid='B00002JXFH', r_ui=4.0, est=4.346478570455973, details={'was_impossible': False}),
#  Prediction(uid='A10TQRXANRYQ6D', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='ATTJRQMPNLEPR', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2MMKBLXP0LKD5', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A2K4L3QL76RSG6', iid='B00004SQET', r_ui=5.0, est=4.527269794556454, details={'was_impossible': False}),
#  Prediction(uid='A30XHDCAO6MAEV', iid='B00004SB92', r_ui=4.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='A2IYLUSMWY6T4A', iid='B00004TBLW', r_ui=5.0, est=4.317145628298537, details={'was_impossible': False}),
#  Prediction(uid='A1CLCC5UY1S149', iid='B000031KIM', r_ui=4.0, est=4.196168143434032, details={'was_impossible': False}),
#  Prediction(uid='A3VE7Q12BXFTLF', iid='140053271X', r_ui=2.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A27W2XD4XB3GIR', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A211YJL5P91NPR', iid='B00002SWUE', r_ui=5.0, est=4.2638117576387575, details={'was_impossible': False}),
#  Prediction(uid='AVNZL6B5EG67H', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A6GJ70R1C65QD', iid='B00004S9AK', r_ui=5.0, est=4.300347175606129, details={'was_impossible': False}),
#  Prediction(uid='A1ZAC9PEL151EZ', iid='B00003CWDH', r_ui=4.0, est=4.404500465144036, details={'was_impossible': False}),
#  Prediction(uid='A6152RT4CQMLV', iid='B00001OXQ9', r_ui=5.0, est=4.338158102379127, details={'was_impossible': False}),
#  Prediction(uid='AV8WSX4H6O382', iid='B00001W0DH', r_ui=5.0, est=4.110985964106741, details={'was_impossible': False}),
#  Prediction(uid='A1FHA9KW2QW86E', iid='B00001P4XA', r_ui=4.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A19SXS5PEC80UQ', iid='B00000J1EQ', r_ui=5.0, est=4.159199171733841, details={'was_impossible': False}),
#  Prediction(uid='A2J2DVZW2O9IZ6', iid='B00003CWDQ', r_ui=5.0, est=4.2144362706398955, details={'was_impossible': False}),
#  Prediction(uid='A48A4I1KUEFUB', iid='B000001ON6', r_ui=5.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='A2Q2NV74EUJL5', iid='B00000K13L', r_ui=5.0, est=4.564104560708621, details={'was_impossible': False}),
#  Prediction(uid='A18B6RZD3H0MBI', iid='B00001P4XH', r_ui=5.0, est=3.9926238149530437, details={'was_impossible': False}),
#  Prediction(uid='A1CA40102FA5N0', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A27U7Z62JUZAXK', iid='B00000J1QR', r_ui=5.0, est=4.152201977600076, details={'was_impossible': False}),
#  Prediction(uid='A3E4VQ06C4L6DX', iid='9983891212', r_ui=4.0, est=4.453473789533362, details={'was_impossible': False}),
#  Prediction(uid='AF9TX1AH6OR65', iid='B00000J1V5', r_ui=5.0, est=4.600423244099123, details={'was_impossible': False}),
#  Prediction(uid='A2TTAOZX77R1P0', iid='B00000JSGF', r_ui=2.0, est=3.9836250991699536, details={'was_impossible': False}),
#  Prediction(uid='A1J32G7DD68CDR', iid='B00004SABB', r_ui=4.0, est=3.99562124837432, details={'was_impossible': False}),
#  Prediction(uid='A36PD93BKT953', iid='B00001X5AL', r_ui=5.0, est=3.7745566673765563, details={'was_impossible': False}),
#  Prediction(uid='A3AN4MM6Y9O4RQ', iid='B00001QEMF', r_ui=4.0, est=4.476000262708626, details={'was_impossible': False}),
#  Prediction(uid='A11NLVWA0MTSGH', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='AED5QZGBW0A38', iid='B00002EQCW', r_ui=5.0, est=4.672902442196928, details={'was_impossible': False}),
#  Prediction(uid='A28D5YD793ZAOA', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A3S7Z3RXO7HC1U', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A2WBT0TCU7YHW8', iid='B00000DM9W', r_ui=5.0, est=4.584937904717025, details={'was_impossible': False}),
#  Prediction(uid='ACKX6S6COWZX4', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1HWOL721EEGZI', iid='B00000JD34', r_ui=5.0, est=3.9442921614009085, details={'was_impossible': False}),
#  Prediction(uid='A35Z26M69ZK7EJ', iid='B00000J1SC', r_ui=3.0, est=4.100258217334701, details={'was_impossible': False}),
#  Prediction(uid='A263OQLPKEXPF1', iid='0972683275', r_ui=5.0, est=4.44642983579106, details={'was_impossible': False}),
#  Prediction(uid='A1H6XD5G9ZOPEV', iid='B00004SY4H', r_ui=5.0, est=4.725937500037273, details={'was_impossible': False}),
#  Prediction(uid='AA0Q11FCAU4BM', iid='B00000J6WY', r_ui=3.0, est=3.920859088041669, details={'was_impossible': False}),
#  Prediction(uid='A1WKJRJRP3BLVS', iid='B00001P4ZH', r_ui=3.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='A1EXTEQC0ZFMEY', iid='B00001OWYM', r_ui=1.0, est=3.2526195146212795, details={'was_impossible': False}),
#  Prediction(uid='ALRN51WC0BZHL', iid='1400698987', r_ui=5.0, est=4.288684006851187, details={'was_impossible': False}),
#  Prediction(uid='A2ZJIHSRFBW6MH', iid='B00000J4FS', r_ui=5.0, est=3.9664069885343927, details={'was_impossible': False}),
#  Prediction(uid='A3LSL926C5CBVR', iid='B00000JMUG', r_ui=5.0, est=3.53078948242854, details={'was_impossible': False}),
#  Prediction(uid='AY9F34HZ46ZG', iid='B00001P4ZH', r_ui=5.0, est=4.453440272098132, details={'was_impossible': False}),
#  Prediction(uid='APXJEGIZH1EZ6', iid='B00000J1EQ', r_ui=5.0, est=4.159199171733841, details={'was_impossible': False}),
#  Prediction(uid='A1BHPKGAYGJW3D', iid='B00004S9AK', r_ui=5.0, est=4.300347175606129, details={'was_impossible': False}),
#  Prediction(uid='AB5IRN4ZRV0Q8', iid='B00001ZWXA', r_ui=5.0, est=4.310219499683008, details={'was_impossible': False}),
#  Prediction(uid='A1CGIM9GAZ88AN', iid='B00001W0EQ', r_ui=4.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='AVX4WIV5O4F93', iid='B00001P4XH', r_ui=4.0, est=3.9577437940224183, details={'was_impossible': False}),
#  Prediction(uid='A1OSBRFDRU2053', iid='B00004SB92', r_ui=2.0, est=4.002145025880293, details={'was_impossible': False}),
#  Prediction(uid='AD50TWQOM8W4G', iid='B00004T0RC', r_ui=5.0, est=4.519804508773945, details={'was_impossible': False}),
#  Prediction(uid='A1LSKU69JFXRX4', iid='B00004RC2D', r_ui=2.0, est=4.37887066449998, details={'was_impossible': False}),
#  Prediction(uid='AIYJVTMU58D9H', iid='B000001ON6', r_ui=4.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='A1RW48VM5K7UU', iid='B00001P4XA', r_ui=5.0, est=3.8694218451105855, details={'was_impossible': False}),
#  Prediction(uid='A3NEQTVZYA4ZCE', iid='B00003G1RG', r_ui=5.0, est=4.5290781289328566, details={'was_impossible': False}),
#  Prediction(uid='AXOGY6U4TVIK7', iid='B00001WRSJ', r_ui=5.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A2VH2MXEKNHLXQ', iid='B000001ON6', r_ui=5.0, est=3.871168100552785, details={'was_impossible': False}),
#  Prediction(uid='A3RQA01A692NQO', iid='B00003WGP5', r_ui=4.0, est=4.250944099281516, details={'was_impossible': False}),
#  Prediction(uid='A29UIL27MXCK1O', iid='B00001W0EQ', r_ui=4.0, est=3.7420349000714674, details={'was_impossible': False}),
#  Prediction(uid='A1LU0VERJO7ZD', iid='B00000J1TX', r_ui=5.0, est=4.307202036886721, details={'was_impossible': False}),
#  Prediction(uid='A7WM1RJQQ68AR', iid='B00001WRSJ', r_ui=4.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='AUGYYW59SEN5', iid='1400532655', r_ui=5.0, est=3.7690335346469035, details={'was_impossible': False}),
#  Prediction(uid='A1DD0N949AYDTG', iid='B00001WRSJ', r_ui=4.0, est=4.610596159036621, details={'was_impossible': False}),
#  Prediction(uid='A1AYNTHLTX8KG1', iid='B00003G1RG', r_ui=4.0, est=4.5290781289328566, details={'was_impossible': False}),
#  Prediction(uid='A3E9QB302HOMUO', iid='B00001OWYM', r_ui=5.0, est=3.2526195146212795, details={'was_impossible': False}),
#  Prediction(uid='A2A3FVY86JZIZV', iid='140053271X', r_ui=5.0, est=3.859642962289266, details={'was_impossible': False}),
#  Prediction(uid='A1LUMWAVTPP043', iid='B00000JDHV', r_ui=1.0, est=3.753940260655742, details={'was_impossible': False}),
#  Prediction(uid='A3BXKP6QVYHFIO', iid='B00004T8R2', r_ui=1.0, est=4.2679863504882345, details={'was_impossible': False}),
#  ...]

# %%
# get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 1.2507
# 1.2506757334191487

# %%
trainset = algo.trainset
print(algo.__class__.__name__)
# Out:
# BaselineOnly

# %% [markdown]
# # Model-based collaborative filtering system
#
# The goal is to train models to be able to make predictions. For example, we could use existing user-item interactions to train a model to predict the top-5 items that a user might like the most. One advantage of these methods is that they are able to recommend a larger number of items to a larger number of users, compared to other methods like memory based approach. They have large coverage, even when working with large sparse matrices.

# %%
new_df1=new_df.head(10000)
ratings_matrix = new_df1.pivot_table(values='Rating', index='userId', columns='productId', fill_value=0)
ratings_matrix.head()
# Out:
# productId              0972683275  1400501466  1400501520  1400501776  \
# userId
# A01852072Z7B68UHLI5UG           0           0           0           0
# A0266076X6KPZ6CCHGVS            0           0           0           0
# A0293130VTX2ZXA70JQS            5           0           0           0
# A030530627MK66BD8V4LN           4           0           0           0
# A0571176384K8RBNKGF8O           0           0           0           0
#
# productId              1400532620  1400532655  140053271X  1400532736  \
# userId
# A01852072Z7B68UHLI5UG           0           0           0           0
# A0266076X6KPZ6CCHGVS            0           0           0           0
# A0293130VTX2ZXA70JQS            0           0           0           0
# A030530627MK66BD8V4LN           0           0           0           0
# A0571176384K8RBNKGF8O           0           0           0           0
#
# productId              1400599997  1400698987  ...  B00000JFMK  B00000JHWX  \
# userId                                         ...
# A01852072Z7B68UHLI5UG           0           0  ...           0           0
# A0266076X6KPZ6CCHGVS            0           0  ...           0           0
# A0293130VTX2ZXA70JQS            0           0  ...           0           0
# A030530627MK66BD8V4LN           0           0  ...           0           0
# A0571176384K8RBNKGF8O           0           0  ...           0           0
#
# productId              B00000JI4F  B00000JII6  B00000JMUG  B00000JPPI  \
# userId
# A01852072Z7B68UHLI5UG           0           0           0           0
# A0266076X6KPZ6CCHGVS            0           0           0           0
# A0293130VTX2ZXA70JQS            0           0           0           0
# A030530627MK66BD8V4LN           0           0           0           0
# A0571176384K8RBNKGF8O           0           0           0           0
#
# productId              B00000JSGF  B00000JYLO  B00000JYWQ  B00000K135
# userId
# A01852072Z7B68UHLI5UG           0           0           0           0
# A0266076X6KPZ6CCHGVS            0           0           0           0
# A0293130VTX2ZXA70JQS            0           0           0           0
# A030530627MK66BD8V4LN           0           0           0           0
# A0571176384K8RBNKGF8O           0           0           0           0
#
# [5 rows x 76 columns]

# %% [markdown]
# As expected, the utility matrix obtaned above is sparce, I have filled up the unknown values wth 0.

# %%
ratings_matrix.shape
# Out:
# (9832, 76)

# %% [markdown]
# Transposing the matrix

# %%
X = ratings_matrix.T
X.head()
# Out:
# userId      A01852072Z7B68UHLI5UG  A0266076X6KPZ6CCHGVS  A0293130VTX2ZXA70JQS  \
# productId
# 0972683275                      0                     0                     5
# 1400501466                      0                     0                     0
# 1400501520                      0                     0                     0
# 1400501776                      0                     0                     0
# 1400532620                      0                     0                     0
#
# userId      A030530627MK66BD8V4LN  A0571176384K8RBNKGF8O  \
# productId
# 0972683275                      4                      0
# 1400501466                      0                      0
# 1400501520                      0                      0
# 1400501776                      0                      0
# 1400532620                      0                      0
#
# userId      A0590501PZ7HOWJKBGQ4  A0641581307AKT5MAOU0Q  \
# productId
# 0972683275                     0                      0
# 1400501466                     0                      0
# 1400501520                     0                      0
# 1400501776                     0                      0
# 1400532620                     0                      0
#
# userId      A076219533YHEV2LJO988  A0821988FXKFYX53V4QG  \
# productId
# 0972683275                      0                     0
# 1400501466                      0                     0
# 1400501520                      0                     0
# 1400501776                      0                     0
# 1400532620                      0                     0
#
# userId      A099626739FNCRNHIKBCG  ...  AZWOPBY75SGAM  AZX0ZDVAFMN78  \
# productId                          ...
# 0972683275                      0  ...              0              0
# 1400501466                      0  ...              0              0
# 1400501520                      3  ...              0              0
# 1400501776                      0  ...              0              0
# 1400532620                      0  ...              0              0
#
# userId      AZX5LAN9JEAFF  AZX7I110AF0W2  AZXKUK895VGSM  AZXP46IB63PU8  \
# productId
# 0972683275              0              0              0              0
# 1400501466              0              0              0              0
# 1400501520              0              0              0              0
# 1400501776              0              0              0              0
# 1400532620              0              0              0              0
#
# userId      AZYTSU42BZ7TP  AZZGJ2KMWB7R  AZZMV5VT9W7Y8  AZZST8OYL5P4Q
# productId
# 0972683275              0             0              0              0
# 1400501466              0             0              0              0
# 1400501520              0             0              0              0
# 1400501776              0             0              1              0
# 1400532620              0             0              0              0
#
# [5 rows x 9832 columns]

# %%
X.shape
# Out:
# (76, 9832)

# %% [markdown]
# Unique products in subset of data

# %%
X1 = X

# %%
#Decomposing the Matrix
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (76, 10)

# %%
#Correlation Matrix

correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (76, 76)

# %%
X.index[70]
# Out:
# 'B00000JMUG'

# %% [markdown]
# Index # of product ID purchased by customer

# %%
i = "B00000JMUG"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 70

# %% [markdown]
# Correlation for all items with the item purchased by this customer based on items rated by other customers people who bought the same product

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (76,)

# %% [markdown]
# Recommending top 5 highly correlated products in sequence

# %%
Recommend = list(X.index[correlation_product_ID > 0.65])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:5]
# Out:
# ['6301977173', '7214047977', '9983891212', '9984984354', 'B00000J1EP']

# %% [markdown]
# Above are the top 5 products to be displayed by the recommendation system to the above customer based on the purchase history of other customers in the website.

# %% [markdown]
# # Summary:
#
# There are different types of the recommendations systems :-
#
# 1. Popularity based systems :- This model works by recommeding items viewed and purchased by most people and are rated high.This is not a personalized recommendation.
# 2. Classification model based:- This model works by understanding the features of the user and applying the classification algorithm to decide whether the user is/ will be interested or not in the product.
# 3. Content based recommedations:- This is based on the information on the contents of the item rather than on the user opinions.The main idea is if the user likes an item then he or she will like the "other" similar item.
# 4. Collaberative Filtering:- It is based on assumption that people like things similar to other things they like, and things that are liked by other people with similar taste. it is mainly of two types:
#  a) User-User
#  b) Item -Item
#
# 5. Hybrid Approaches:- This system approach is to combine collaborative filtering, content-based filtering, and other approaches .
# 6. Association rule mining :- Association rules capture the relationships between items based on their patterns of co-occurrence across transactions.(Apriori principle). Market Basket Analysis is a popular application of Association Rules.
